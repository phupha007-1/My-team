# %% [markdown]
# <a href="https://colab.research.google.com/github/phupha007-1/My-team/blob/main/13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("a")
# Out:
# a
